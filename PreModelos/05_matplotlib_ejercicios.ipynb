# %% [markdown]
# **1)** A partir de estos datos, que representan las personas matriculadas en distintos niveles de formación.
# Creamos el número de personas de forma aleatoria con numpy, np.random.rand(n), crea n números aleatorios entre 0 y 1.
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# años = ["2011", "2012", "2013", "2014", "2015",
#         "2016", "2017", "2018", "2019", "2020"]
#
# nivel1 = np.random.rand(10)*100 # Los multiplicamos por 100
# nivel2 = np.random.rand(10)*200 + 100
# nivel3 = np.random.rand(10)*300 + 200
# nivel4 = np.random.rand(10)*400 + 300
# nivel5 = np.random.rand(10)*500 + 400
# ```
#
# Crear una gráfica para representar los niveles de formación.
#
# Añadir estilo de líneas, colores y marcas.
#
# Añadir leyendas, títulos, etiquetas a los ejes.
#
# Personalizar el eje de puntos de 0 a 1000 en incremento de 50, utilizando np.arange(0, 1001, 50)
#
# Que se muestre el grid.
#
# Intentad que la salida sea como la que se muestra:
#
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

años = ["2011", "2012", "2013", "2014", "2015",
        "2016", "2017", "2018", "2019", "2020"]

nivel1 = np.random.rand(10)*100 # Los multiplicamos por 100
nivel2 = np.random.rand(10)*200 + 100
nivel3 = np.random.rand(10)*300 + 200
nivel4 = np.random.rand(10)*400 + 300
nivel5 = np.random.rand(10)*500 + 400

# Crear una gráfica para representar los niveles de formación.
plt.plot(años, nivel1, linestyle='solid', color='purple', marker='<', label='Nivel 1')
plt.show()
# Añadir estilo de líneas, colores y marcas.

# Añadir leyendas, títulos, etiquetas a los ejes.

# Personalizar el eje de puntos de 0 a 1000 en incremento de 50, utilizando np.arange(0, 1001, 50)

# Que se muestre el grid.

# Intentad que la salida sea como la que se muestra:

# %% [markdown]
# **2)**	Realizar ahora un gráfico de barras para los datos de todos los niveles,
#
# siendo en este caso el valor de X el numero de muestras que tenemos de años, es decir, de 0 a 9..
#
# Por ejemplo, sólo para el Nivel 1, sería ...:
#
#
# ```python
# #Genera el eje x, valores de 0 a 9 enteros
# eje_x = np.arange(0, 10)
# plt.bar(eje_x, nivel1, width=1/5)
# ```
#
#
# ![image.png](attachment:image.png)
#
# Sin embargo, nosotros quetemos pintar todos los niveles, de manera que el resultado sea:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# **3)**	Dibuja ahora un gráfico de dispersión con esos datos, utilizando también el eje_x de 0 a 9, y poniendo una marca a cada dato.
#
# ![image.png](attachment:image.png)
